# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! unzip /content/drive/MyDrive/CS2/train.zip -d train
# Out:
# Archive:  /content/drive/MyDrive/CS2/train.zip
#   inflating: train/00204008d.flac
#   inflating: train/003b04435.flac
#   inflating: train/003bec244.flac
#   inflating: train/005f1f9a5.flac
#   inflating: train/006ab765f.flac
#   inflating: train/0072f0839.flac
#   inflating: train/0079ff47b.flac
#   inflating: train/007f87ba2.flac
#   inflating: train/00834f88e.flac
#   inflating: train/008c9c381.flac
#   inflating: train/0099c367b.flac
#   inflating: train/009aa1c8f.flac
#   inflating: train/009b760e6.flac
#   inflating: train/009fbc7b4.flac
#   inflating: train/00ad36516.flac
#   inflating: train/00b404881.flac
#   inflating: train/00d442df7.flac
#   inflating: train/00e3525a2.flac
#   inflating: train/00f3b3c1e.flac
#   inflating: train/011f25080.flac
#   inflating: train/013716dbf.flac
#   inflating: train/015113cad.flac
#   inflating: train/0151b7d20.flac
#   inflating: train/015aa6c7c.flac
#   inflating: train/016240b9a.flac
#   inflating: train/017165b59.flac
#   inflating: train/0171866c7.flac
#   inflating: train/0178fe09a.flac
#   inflating: train/017d43bd0.flac
#   inflating: train/01a976045.flac
#   inflating: train/01b41f92b.flac
#   inflating: train/01cd1b90e.flac
#   inflating: train/01ceb73a1.flac
#   inflating: train/01d1aeb9a.flac
#   inflating: train/01dd6474a.flac
#   inflating: train/01e8c8d72.flac
#   inflating: train/0201197ec.flac
#   inflating: train/0209f7ab2.flac
#   inflating: train/021e8f7aa.flac
#   inflating: train/022f801bc.flac
#   inflating: train/023e22a5e.flac
#   inflating: train/0268057eb.flac
#   inflating: train/0275e127d.flac
#   inflating: train/0281e4332.flac
#   inflating: train/0295e3234.flac
#   inflating: train/0297d886e.flac
#   inflating: train/02a9de85e.flac
#   inflating: train/02b9a8ab9.flac
#   inflating: train/02f79ea92.flac
#   inflating: train/03049a445.flac
#   inflating: train/0313e82cf.flac
#   inflating: train/0319f2979.flac
#   inflating: train/032cb2915.flac
#   inflating: train/0337b0224.flac
#   inflating: train/034868b19.flac
#   inflating: train/034f18a3e.flac
#   inflating: train/035095d4d.flac
#   inflating: train/036726d38.flac
#   inflating: train/0384c1b79.flac
#   inflating: train/038dfd032.flac
#   inflating: train/03971ab79.flac
#   inflating: train/039dd83e7.flac
#   inflating: train/03a7d9ad6.flac
#   inflating: train/03ac92720.flac
#   inflating: train/03b0b2911.flac
#   inflating: train/03b96f209.flac
#   inflating: train/03c7f5878.flac
#   inflating: train/03d77fede.flac
#   inflating: train/03e8c2dc8.flac
#   inflating: train/03f26cc6b.flac
#   inflating: train/0406f2e0c.flac
#   inflating: train/04230cfcd.flac
#   inflating: train/042638dad.flac
#   inflating: train/043356ff8.flac
#   inflating: train/0434aa9f1.flac
#   inflating: train/044215cde.flac
#   inflating: train/044f7a7e5.flac
#   inflating: train/0471295f3.flac
#   inflating: train/048ac16fc.flac
#   inflating: train/048c43993.flac
#   inflating: train/048eb9ffb.flac
#   inflating: train/04975ecd8.flac
#   inflating: train/049a76094.flac
#   inflating: train/049bbf288.flac
#   inflating: train/04a16424c.flac
#   inflating: train/04af4dc74.flac
#   inflating: train/04d6b1fc1.flac
#   inflating: train/04e36e3f3.flac
#   inflating: train/04e3e4104.flac
#   inflating: train/04e70a8e3.flac
#   inflating: train/04e8c27b7.flac
#   inflating: train/04e90f0ff.flac
#   inflating: train/04efd6001.flac
#   inflating: train/04fb46abf.flac
#   inflating: train/0509303a5.flac
#   inflating: train/050d0ca85.flac
#   inflating: train/0511d5770.flac
#   inflating: train/05194d95e.flac
#   inflating: train/051cddb21.flac
#   inflating: train/052990102.flac
#   inflating: train/053aeb7bd.flac
#   inflating: train/053c2bfa7.flac
#   inflating: train/055088446.flac
#   inflating: train/055d22517.flac
#   inflating: train/057802c25.flac
#   inflating: train/05ac12261.flac
#   inflating: train/05b9c974c.flac
#   inflating: train/05be38697.flac
#   inflating: train/05f4c463d.flac
#   inflating: train/05f8c0f2f.flac
#   inflating: train/05fddb6fb.flac
#   inflating: train/0608aef17.flac
#   inflating: train/064d24348.flac
#   inflating: train/065012e32.flac
#   inflating: train/06523229a.flac
#   inflating: train/065f57740.flac
#   inflating: train/0669568b1.flac
#   inflating: train/067f49f8b.flac
#   inflating: train/06877eed1.flac
#   inflating: train/068f1b8e2.flac
#   inflating: train/069d5cd00.flac
#   inflating: train/069f97b69.flac
#   inflating: train/06a0c48c9.flac
#   inflating: train/06c44d203.flac
#   inflating: train/06d8a3bae.flac
#   inflating: train/06d95a7e8.flac
#   inflating: train/06defceab.flac
#   inflating: train/06df23093.flac
#   inflating: train/06f60bd19.flac
#   inflating: train/06fffb5aa.flac
#   inflating: train/070bbf5f9.flac
#   inflating: train/071632d14.flac
#   inflating: train/071823da4.flac
#   inflating: train/072394f9f.flac
#   inflating: train/073e4d908.flac
#   inflating: train/074978766.flac
#   inflating: train/074cf066a.flac
#   inflating: train/0759cfd57.flac
#   inflating: train/076ba0261.flac
#   inflating: train/07732dc66.flac
#   inflating: train/07748f4da.flac
#   inflating: train/077b08bdb.flac
#   inflating: train/078788674.flac
#   inflating: train/079cef4b3.flac
#   inflating: train/07b5f24b6.flac
#   inflating: train/07c08e332.flac
#   inflating: train/07d1687e0.flac
#   inflating: train/07dcf40f7.flac
#   inflating: train/07e6ea0f8.flac
#   inflating: train/07edb03ee.flac
#   inflating: train/07f1227b0.flac
#   inflating: train/07f7c929f.flac
#   inflating: train/081028e00.flac
#   inflating: train/08167c1c1.flac
#   inflating: train/0819bd965.flac
#   inflating: train/08243f982.flac
#   inflating: train/0839c1940.flac
#   inflating: train/083e92382.flac
#   inflating: train/085457fb0.flac
#   inflating: train/08659843d.flac
#   inflating: train/0868752e2.flac
#   inflating: train/0876d30ac.flac
#   inflating: train/087e68d29.flac
#   inflating: train/08830e5c1.flac
#   inflating: train/088a32d3e.flac
#   inflating: train/088d88a09.flac
#   inflating: train/0898c36e0.flac
#   inflating: train/08ad9244f.flac
#   inflating: train/08d0d47c3.flac
#   inflating: train/08db743d0.flac
#   inflating: train/08dc46957.flac
#   inflating: train/08f1d28d2.flac
#   inflating: train/08fce68af.flac
#   inflating: train/090ae427d.flac
#   inflating: train/091a9a48c.flac
#   inflating: train/091d8cc72.flac
#   inflating: train/09315d9bf.flac
#   inflating: train/094641bb2.flac
#   inflating: train/094b0ce8e.flac
#   inflating: train/094b72326.flac
#   inflating: train/095a6d245.flac
#   inflating: train/095ab4bbb.flac
#   inflating: train/095e942f1.flac
#   inflating: train/0968aea09.flac
#   inflating: train/097a91620.flac
#   inflating: train/09a946316.flac
#   inflating: train/09bb67de8.flac
#   inflating: train/09bfcc3a5.flac
#   inflating: train/09faf10ca.flac
#   inflating: train/09fe8c9ea.flac
#   inflating: train/0a1660b55.flac
#   inflating: train/0a29fd478.flac
#   inflating: train/0a33527e9.flac
#   inflating: train/0a350d11c.flac
#   inflating: train/0a4e7e350.flac
#   inflating: train/0a4f02024.flac
#   inflating: train/0a65cc78c.flac
#   inflating: train/0a698a702.flac
#   inflating: train/0a864bdf1.flac
#   inflating: train/0a8974fbc.flac
#   inflating: train/0a9143370.flac
#   inflating: train/0a98ad3b6.flac
#   inflating: train/0a9a53ccc.flac
#   inflating: train/0a9cdd8a5.flac
#   inflating: train/0a9ec9e31.flac
#   inflating: train/0aa32b6ab.flac
#   inflating: train/0ab6aa734.flac
#   inflating: train/0ad908b48.flac
#   inflating: train/0ad94a523.flac
#   inflating: train/0adec440a.flac
#   inflating: train/0b231d23d.flac
#   inflating: train/0b2fa3f80.flac
#   inflating: train/0b306a59b.flac
#   inflating: train/0b3479649.flac
#   inflating: train/0b395f647.flac
#   inflating: train/0b3ef9c4e.flac
#   inflating: train/0b53368a4.flac
#   inflating: train/0b5a33bb8.flac
#   inflating: train/0b608ad6b.flac
#   inflating: train/0b7b8f27f.flac
#   inflating: train/0b866b593.flac
#   inflating: train/0bb2c7030.flac
#   inflating: train/0bca40ab7.flac
#   inflating: train/0bd7dc31b.flac
#   inflating: train/0bef9aa9e.flac
#   inflating: train/0bf67aa1f.flac
#   inflating: train/0c06d49cb.flac
#   inflating: train/0c07848ae.flac
#   inflating: train/0c10d30c2.flac
#   inflating: train/0c1bcc7ba.flac
#   inflating: train/0c2124550.flac
#   inflating: train/0c3c81b14.flac
#   inflating: train/0c448e77c.flac
#   inflating: train/0c48ed342.flac
#   inflating: train/0c56d87c9.flac
#   inflating: train/0c8046832.flac
#   inflating: train/0c8072185.flac
#   inflating: train/0c8324b42.flac
#   inflating: train/0c84af39f.flac
#   inflating: train/0c936a1d4.flac
#   inflating: train/0c95479c5.flac
#   inflating: train/0ca70d19c.flac
#   inflating: train/0cb1abcb2.flac
#   inflating: train/0cb4632d6.flac
#   inflating: train/0cbd53978.flac
#   inflating: train/0cd206677.flac
#   inflating: train/0cf1a2ecd.flac
#   inflating: train/0cfe92ae1.flac
#   inflating: train/0d10c0574.flac
#   inflating: train/0d1d831a8.flac
#   inflating: train/0d1dd84cd.flac
#   inflating: train/0d25045a9.flac
#   inflating: train/0d2c9416c.flac
#   inflating: train/0d42350fc.flac
#   inflating: train/0d489b79b.flac
#   inflating: train/0d4a24cc8.flac
#   inflating: train/0d503b7e8.flac
#   inflating: train/0d5f3f252.flac
#   inflating: train/0d62f3d1a.flac
#   inflating: train/0d6e47220.flac
#   inflating: train/0d6eb26fc.flac
#   inflating: train/0d7267fbd.flac
#   inflating: train/0d79fc2f5.flac
#   inflating: train/0dbcf304b.flac
#   inflating: train/0dceae04a.flac
#   inflating: train/0dd5a2bdb.flac
#   inflating: train/0de868a8d.flac
#   inflating: train/0de9136c8.flac
#   inflating: train/0e034f968.flac
#   inflating: train/0e0a36d7a.flac
#   inflating: train/0e0f7e141.flac
#   inflating: train/0e16de967.flac
#   inflating: train/0e1f12717.flac
#   inflating: train/0e297a752.flac
#   inflating: train/0e29d05ed.flac
#   inflating: train/0e2e4ac19.flac
#   inflating: train/0e30535d1.flac
#   inflating: train/0e45aa8d9.flac
#   inflating: train/0e4a29539.flac
#   inflating: train/0e4ffa297.flac
#   inflating: train/0e57bfc3a.flac
#   inflating: train/0e5a03b1f.flac
#   inflating: train/0e7232b88.flac
#   inflating: train/0e755cce4.flac
#   inflating: train/0e799da44.flac
#   inflating: train/0e85a95f7.flac
#   inflating: train/0e952fb8a.flac
#   inflating: train/0ea8ea68a.flac
#   inflating: train/0eabaff87.flac
#   inflating: train/0eb2079ea.flac
#   inflating: train/0ebe96f07.flac
#   inflating: train/0ec8d53b3.flac
#   inflating: train/0eda4b0d1.flac
#   inflating: train/0efea8645.flac
#   inflating: train/0effcf241.flac
#   inflating: train/0f00a85fd.flac
#   inflating: train/0f08c882f.flac
#   inflating: train/0f1ab51d5.flac
#   inflating: train/0f27d5197.flac
#   inflating: train/0f51600c8.flac
#   inflating: train/0f52b6177.flac
#   inflating: train/0f571d336.flac
#   inflating: train/0f6c26048.flac
#   inflating: train/0f8cadb4a.flac
#   inflating: train/0f8ea71e4.flac
#   inflating: train/0f99800b7.flac
#   inflating: train/0f9fcb0c4.flac
#   inflating: train/0fa42b741.flac
#   inflating: train/0faa97c9e.flac
#   inflating: train/0fc62dd3c.flac
#   inflating: train/0fcc4abfb.flac
#   inflating: train/0fd62f91b.flac
#   inflating: train/0fe894410.flac
#   inflating: train/0ffb11627.flac
#   inflating: train/100e4ddc9.flac
#   inflating: train/1014e6d3e.flac
#   inflating: train/1028dc3ed.flac
#   inflating: train/1038e06ae.flac
#   inflating: train/103db6411.flac
#   inflating: train/1050560e3.flac
#   inflating: train/10710452b.flac
#   inflating: train/1076d38c9.flac
#   inflating: train/10b8ea228.flac
#   inflating: train/10c54cb3d.flac
#   inflating: train/10cba63d4.flac
#   inflating: train/10dae79ed.flac
#   inflating: train/10debeacf.flac
#   inflating: train/10fc9a772.flac
#   inflating: train/10fd3d93d.flac
#   inflating: train/1100df69a.flac
#   inflating: train/11075cf79.flac
#   inflating: train/110a7678f.flac
#   inflating: train/11126b0f9.flac
#   inflating: train/111a3f984.flac
#   inflating: train/111e16fce.flac
#   inflating: train/11246c3ec.flac
#   inflating: train/113a2c172.flac
#   inflating: train/1171e7dfa.flac
#   inflating: train/119563bc0.flac
#   inflating: train/119b154cc.flac
#   inflating: train/11a475baa.flac
#   inflating: train/11a52d37a.flac
#   inflating: train/11bafff5d.flac
#   inflating: train/11bd74ea1.flac
#   inflating: train/11c2c02e5.flac
#   inflating: train/11f1747a9.flac
#   inflating: train/11fd2b63e.flac
#   inflating: train/1217fa38e.flac
#   inflating: train/122f51b0c.flac
#   inflating: train/1263c23c8.flac
#   inflating: train/126fee4cd.flac
#   inflating: train/127322909.flac
#   inflating: train/128b7044e.flac
#   inflating: train/1295eddd3.flac
#   inflating: train/12a12f0fa.flac
#   inflating: train/12ab8cc1e.flac
#   inflating: train/12ac9ebdb.flac
#   inflating: train/12c6e385e.flac
#   inflating: train/12c876ba3.flac
#   inflating: train/12c929f28.flac
#   inflating: train/12d05c25f.flac
#   inflating: train/12dd4abc1.flac
#   inflating: train/12ec1d4cb.flac
#   inflating: train/12f849a4f.flac
#   inflating: train/131dc7876.flac
#   inflating: train/132719309.flac
#   inflating: train/133001416.flac
#   inflating: train/134c64639.flac
#   inflating: train/13511f7bd.flac
#   inflating: train/1354af056.flac
#   inflating: train/1375a05d1.flac
#   inflating: train/137915490.flac
#   inflating: train/1383208d3.flac
#   inflating: train/13acead83.flac
#   inflating: train/13c678c1d.flac
#   inflating: train/13c887207.flac
#   inflating: train/13ccbd76b.flac
#   inflating: train/13de5cabb.flac
#   inflating: train/13e00ac51.flac
#   inflating: train/13ebb8491.flac
#   inflating: train/13ebd05a8.flac
#   inflating: train/13f64f898.flac
#   inflating: train/13f7437c5.flac
#   inflating: train/1414bbe17.flac
#   inflating: train/141675c80.flac
#   inflating: train/14218200a.flac
#   inflating: train/143674b5d.flac
#   inflating: train/1441fe517.flac
#   inflating: train/144578225.flac
#   inflating: train/147b41b13.flac
#   inflating: train/147c904f2.flac
#   inflating: train/14809568f.flac
#   inflating: train/1481df66a.flac
#   inflating: train/148683250.flac
#   inflating: train/148abcbba.flac
#   inflating: train/148f39782.flac
#   inflating: train/14948ff80.flac
#   inflating: train/1498304c0.flac
#   inflating: train/149c502b8.flac
#   inflating: train/14ae8569b.flac
#   inflating: train/14b0abaed.flac
#   inflating: train/14bd9c39c.flac
#   inflating: train/14c10dbd8.flac
#   inflating: train/14c397838.flac
#   inflating: train/14c737741.flac
#   inflating: train/14c77ad32.flac
#   inflating: train/14d2427dd.flac
#   inflating: train/14d467153.flac
#   inflating: train/14dc5a39e.flac
#   inflating: train/14f6cbe5c.flac
#   inflating: train/1504619b7.flac
#   inflating: train/150cf1c58.flac
#   inflating: train/150fe7fc5.flac
#   inflating: train/1511d2c3b.flac
#   inflating: train/1520a52ef.flac
#   inflating: train/1535d0c9b.flac
#   inflating: train/15392c97b.flac
#   inflating: train/1543fd460.flac
#   inflating: train/1545e29b3.flac
#   inflating: train/1559ccd26.flac
#   inflating: train/15675091d.flac
#   inflating: train/156b77dfe.flac
#   inflating: train/157a50231.flac
#   inflating: train/157b73cfe.flac
#   inflating: train/158c5acb6.flac
#   inflating: train/158fd6508.flac
#   inflating: train/15bc6e498.flac
#   inflating: train/15d9e6d8b.flac
#   inflating: train/15ec6a03d.flac
#   inflating: train/160add406.flac
#   inflating: train/160b70831.flac
#   inflating: train/160c65ebc.flac
#   inflating: train/160c76ee7.flac
#   inflating: train/162733a64.flac
#   inflating: train/162a7e399.flac
#   inflating: train/163e86660.flac
#   inflating: train/163fcf5f0.flac
#   inflating: train/16510f04f.flac
#   inflating: train/16553d5cd.flac
#   inflating: train/1669b7e17.flac
#   inflating: train/16714389d.flac
#   inflating: train/16793f0bf.flac
#   inflating: train/1679e323d.flac
#   inflating: train/16859b597.flac
#   inflating: train/16b63fd3b.flac
#   inflating: train/16bce7caf.flac
#   inflating: train/16cadb214.flac
#   inflating: train/16ccddf71.flac
#   inflating: train/16cf75798.flac
#   inflating: train/16fc37168.flac
#   inflating: train/16ffcf223.flac
#   inflating: train/1702d35a0.flac
#   inflating: train/170de6438.flac
#   inflating: train/172bb1373.flac
#   inflating: train/1730a1e46.flac
#   inflating: train/1736150d1.flac
#   inflating: train/17402f75a.flac
#   inflating: train/176a47a27.flac
#   inflating: train/177389698.flac
#   inflating: train/177522951.flac
#   inflating: train/17817e8f8.flac
#   inflating: train/178b835e3.flac
#   inflating: train/178c1a773.flac
#   inflating: train/1795728ba.flac
#   inflating: train/17984a6e7.flac
#   inflating: train/17a13256c.flac
#   inflating: train/17a33abbd.flac
#   inflating: train/17afba68e.flac
#   inflating: train/17b6d882e.flac
#   inflating: train/17bbe2cc4.flac
#   inflating: train/17c319247.flac
#   inflating: train/17ca62c97.flac
#   inflating: train/17ca96791.flac
#   inflating: train/17e28efe7.flac
#   inflating: train/17e97655f.flac
#   inflating: train/17f55e62b.flac
#   inflating: train/17f93f59f.flac
#   inflating: train/180ba3012.flac
#   inflating: train/180d82dca.flac
#   inflating: train/181a23783.flac
#   inflating: train/1821c718c.flac
#   inflating: train/182551d0b.flac
#   inflating: train/1825682f2.flac
#   inflating: train/184322f0e.flac
#   inflating: train/1856bb5c2.flac
#   inflating: train/187255c66.flac
#   inflating: train/1876a3f7b.flac
#   inflating: train/18abb84a3.flac
#   inflating: train/18c47b7f2.flac
#   inflating: train/18d1e6ea1.flac
#   inflating: train/18de8abcc.flac
#   inflating: train/18df43462.flac
#   inflating: train/18e249f36.flac
#   inflating: train/18f850b4d.flac
#   inflating: train/1906c0669.flac
#   inflating: train/1916f60ab.flac
#   inflating: train/1937444f1.flac
#   inflating: train/19442bf58.flac
#   inflating: train/1958ed85a.flac
#   inflating: train/19599b9bc.flac
#   inflating: train/195e5ba43.flac
#   inflating: train/1964b83e1.flac
#   inflating: train/196815671.flac
#   inflating: train/1977da60a.flac
#   inflating: train/1979f2d6b.flac
#   inflating: train/198105510.flac
#   inflating: train/198ab5e4b.flac
#   inflating: train/1990c6e8f.flac
#   inflating: train/19a612a4a.flac
#   inflating: train/19b189d6e.flac
#   inflating: train/19c743954.flac
#   inflating: train/19c9b099c.flac
#   inflating: train/19d786948.flac
#   inflating: train/19dfeda02.flac
#   inflating: train/19eb4ec77.flac
#   inflating: train/19efc5fcb.flac
#   inflating: train/1a0846177.flac
#   inflating: train/1a0b72e93.flac
#   inflating: train/1a24795a3.flac
#   inflating: train/1a3993962.flac
#   inflating: train/1a3bd7725.flac
#   inflating: train/1a57e32e5.flac
#   inflating: train/1a5ccdb50.flac
#   inflating: train/1a5fb3223.flac
#   inflating: train/1a9743443.flac
#   inflating: train/1aa00dc63.flac
#   inflating: train/1aaff8b07.flac
#   inflating: train/1abe6487f.flac
#   inflating: train/1ad5b7e94.flac
#   inflating: train/1adcfb22d.flac
#   inflating: train/1aeb1e9e1.flac
#   inflating: train/1aecf0299.flac
#   inflating: train/1aef4f8ff.flac
#   inflating: train/1af4713d0.flac
#   inflating: train/1af4dac6d.flac
#   inflating: train/1b1bbb090.flac
#   inflating: train/1b3898f7a.flac
#   inflating: train/1b56f87fa.flac
#   inflating: train/1b65b5374.flac
#   inflating: train/1b75b8dfa.flac
#   inflating: train/1b77382c7.flac
#   inflating: train/1b90ba570.flac
#   inflating: train/1b9f7d157.flac
#   inflating: train/1ba9ee79a.flac
#   inflating: train/1bc8c196e.flac
#   inflating: train/1bd29a4bb.flac
#   inflating: train/1c0510f72.flac
#   inflating: train/1c20f63a0.flac
#   inflating: train/1c229b9bf.flac
#   inflating: train/1c25abd65.flac
#   inflating: train/1c30a1874.flac
#   inflating: train/1c388423d.flac
#   inflating: train/1c393d94a.flac
#   inflating: train/1c46aa776.flac
#   inflating: train/1c5798f5a.flac
#   inflating: train/1c73507da.flac
#   inflating: train/1c8b00130.flac
#   inflating: train/1c983c37d.flac
#   inflating: train/1ca8c8af6.flac
#   inflating: train/1cbc05bd3.flac
#   inflating: train/1cd3a6d11.flac
#   inflating: train/1ce06e027.flac
#   inflating: train/1ce9fc3a3.flac
#   inflating: train/1cec601d8.flac
#   inflating: train/1cef26217.flac
#   inflating: train/1cf65a85a.flac
#   inflating: train/1d079d7fc.flac
#   inflating: train/1d1083982.flac
#   inflating: train/1d1a43a51.flac
#   inflating: train/1d215ce18.flac
#   inflating: train/1d2601f32.flac
#   inflating: train/1d2ba4c81.flac
#   inflating: train/1d50498d8.flac
#   inflating: train/1d6371ff5.flac
#   inflating: train/1d6ad1c81.flac
#   inflating: train/1d6d8b162.flac
#   inflating: train/1d751084b.flac
#   inflating: train/1d76cb226.flac
#   inflating: train/1d77efd61.flac
#   inflating: train/1d7d951ef.flac
#   inflating: train/1d7fce396.flac
#   inflating: train/1d8e04120.flac
#   inflating: train/1d949c49d.flac
#   inflating: train/1db9c9a80.flac
#   inflating: train/1dbb4a233.flac
#   inflating: train/1dc65d0a4.flac
#   inflating: train/1dcd5fd12.flac
#   inflating: train/1e05620be.flac
#   inflating: train/1e0841e3e.flac
#   inflating: train/1e0e340e1.flac
#   inflating: train/1e0f86b54.flac
#   inflating: train/1e379f7a6.flac
#   inflating: train/1e3ca155d.flac
#   inflating: train/1e469c124.flac
#   inflating: train/1e5f8d74d.flac
#   inflating: train/1e74db932.flac
#   inflating: train/1e79a2c16.flac
#   inflating: train/1e89a8dc5.flac
#   inflating: train/1e8fbd793.flac
#   inflating: train/1e956d53b.flac
#   inflating: train/1ea1168ad.flac
#   inflating: train/1ea2f04c3.flac
#   inflating: train/1eb2a9113.flac
#   inflating: train/1ebbd65a8.flac
#   inflating: train/1ec33df34.flac
#   inflating: train/1ed1abd44.flac
#   inflating: train/1ee1c030c.flac
#   inflating: train/1ef301db3.flac
#   inflating: train/1ef3e2282.flac
#   inflating: train/1f005146f.flac
#   inflating: train/1f0b4199d.flac
#   inflating: train/1f0fe1c7e.flac
#   inflating: train/1f17893f9.flac
#   inflating: train/1f2260885.flac
#   inflating: train/1f3748a91.flac
#   inflating: train/1f5dd26db.flac
#   inflating: train/1f7abf062.flac
#   inflating: train/1f7d500ee.flac
#   inflating: train/1f834a88d.flac
#   inflating: train/1f8c85d03.flac
#   inflating: train/1f97100c2.flac
#   inflating: train/1f979c4c5.flac
#   inflating: train/1fb27e574.flac
#   inflating: train/1fb41e1c4.flac
#   inflating: train/1fb842413.flac
#   inflating: train/1fb94ae60.flac
#   inflating: train/1fbc39373.flac
#   inflating: train/1fd650183.flac
#   inflating: train/1fe564525.flac
#   inflating: train/1ffa43aae.flac
#   inflating: train/20015050f.flac
#   inflating: train/200656f13.flac
#   inflating: train/200cf55d0.flac
#   inflating: train/2015272b9.flac
#   inflating: train/2026bced7.flac
#   inflating: train/20334f36e.flac
#   inflating: train/2037a18e6.flac
#   inflating: train/20504c921.flac
#   inflating: train/205b1b0e9.flac
#   inflating: train/206bc867c.flac
#   inflating: train/206f79102.flac
#   inflating: train/207c8241d.flac
#   inflating: train/20801bb7d.flac
#   inflating: train/20863cce3.flac
#   inflating: train/208a59bed.flac
#   inflating: train/20bab06f6.flac
#   inflating: train/20be88a43.flac
#   inflating: train/20d726ebb.flac
#   inflating: train/20de9e491.flac
#   inflating: train/20e3f9973.flac
#   inflating: train/2105b0978.flac
#   inflating: train/2105bda77.flac
#   inflating: train/211cde35f.flac
#   inflating: train/2158e19cf.flac
#   inflating: train/215bb7a8d.flac
#   inflating: train/21636af6a.flac
#   inflating: train/219291a8a.flac
#   inflating: train/21a1bad28.flac
#   inflating: train/21a5fffc2.flac
#   inflating: train/21aa5dd1b.flac
#   inflating: train/21ae904e1.flac
#   inflating: train/21c9f1ba3.flac
#   inflating: train/21ce5cb13.flac
#   inflating: train/21e2f2977.flac
#   inflating: train/21e86baf9.flac
#   inflating: train/21ed387c5.flac
#   inflating: train/21f043e30.flac
#   inflating: train/22050fe3f.flac
#   inflating: train/221b20d20.flac
#   inflating: train/226a1b887.flac
#   inflating: train/226b8f9b8.flac
#   inflating: train/226ce47d9.flac
#   inflating: train/22a2faf44.flac
#   inflating: train/22a4f5ea7.flac
#   inflating: train/22b46c334.flac
#   inflating: train/22bfc5978.flac
#   inflating: train/22c65e24d.flac
#   inflating: train/22da462f9.flac
#   inflating: train/22eaad9ca.flac
#   inflating: train/22eefe0aa.flac
#   inflating: train/230152c69.flac
#   inflating: train/2305471d3.flac
#   inflating: train/2308ff2e5.flac
#   inflating: train/2310deb18.flac
#   inflating: train/231809542.flac
#   inflating: train/2319eb4b4.flac
#   inflating: train/231c7fca4.flac
#   inflating: train/2322ec1d3.flac
#   inflating: train/2332a38af.flac
#   inflating: train/23363116f.flac
#   inflating: train/2337c4af2.flac
#   inflating: train/2348f2034.flac
#   inflating: train/236108ef3.flac
#   inflating: train/237fc955f.flac
#   inflating: train/2393b59e0.flac
#   inflating: train/23adb9473.flac
#   inflating: train/23c3b97b6.flac
#   inflating: train/23c7fd2aa.flac
#   inflating: train/23e24033a.flac
#   inflating: train/23edf6e3a.flac
#   inflating: train/23f2f2080.flac
#   inflating: train/23fe200e3.flac
#   inflating: train/2408e155e.flac
#   inflating: train/241406d95.flac
#   inflating: train/2433c9975.flac
#   inflating: train/244497d8d.flac
#   inflating: train/246434b48.flac
#   inflating: train/247aeccaf.flac
#   inflating: train/247d81f2b.flac
#   inflating: train/2482fcbaf.flac
#   inflating: train/24aac801a.flac
#   inflating: train/24b29f809.flac
#   inflating: train/24ccd2df6.flac
#   inflating: train/24d73a0c7.flac
#   inflating: train/24d8e11a9.flac
#   inflating: train/24de2bce7.flac
#   inflating: train/24e76d609.flac
#   inflating: train/24f3b250c.flac
#   inflating: train/250a97577.flac
#   inflating: train/251569711.flac
#   inflating: train/251737ef0.flac
#   inflating: train/25218b040.flac
#   inflating: train/255893f95.flac
#   inflating: train/25619863c.flac
#   inflating: train/2577d25f4.flac
#   inflating: train/258c31cf6.flac
#   inflating: train/258e4642e.flac
#   inflating: train/259a2986d.flac
#   inflating: train/25aabb1b5.flac
#   inflating: train/25baea02d.flac
#   inflating: train/25c229018.flac
#   inflating: train/25c862159.flac
#   inflating: train/25d81e0f5.flac
#   inflating: train/25de8315e.flac
#   inflating: train/25ee19976.flac
#   inflating: train/25f13e8c9.flac
#   inflating: train/26229fc43.flac
#   inflating: train/266e8b635.flac
#   inflating: train/269037690.flac
#   inflating: train/2695a2878.flac
#   inflating: train/26ac05952.flac
#   inflating: train/26ae2763d.flac
#   inflating: train/26c0b52fe.flac
#   inflating: train/26c78f33f.flac
#   inflating: train/270b6c34c.flac
#   inflating: train/27144ca06.flac
#   inflating: train/271747b2d.flac
#   inflating: train/2717a930e.flac
#   inflating: train/271bcbb29.flac
#   inflating: train/27312107f.flac
#   inflating: train/2748697dd.flac
#   inflating: train/2753487e1.flac
#   inflating: train/275a0fc0c.flac
#   inflating: train/27931c6f3.flac
#   inflating: train/27b24b710.flac
#   inflating: train/27b26fe5d.flac
#   inflating: train/27c146a88.flac
#   inflating: train/27c78408d.flac
#   inflating: train/27eb32774.flac
#   inflating: train/27ebe0a69.flac
#   inflating: train/27faf6a9b.flac
#   inflating: train/281865590.flac
#   inflating: train/28250a178.flac
#   inflating: train/28278e5dc.flac
#   inflating: train/282cd2657.flac
#   inflating: train/2845fe611.flac
#   inflating: train/2873d4d54.flac
#   inflating: train/287630bbe.flac
#   inflating: train/287bf77ec.flac
#   inflating: train/288e5d13f.flac
#   inflating: train/28974b8b6.flac
#   inflating: train/28cc5711a.flac
#   inflating: train/28d37d1de.flac
#   inflating: train/28d556f2e.flac
#   inflating: train/28dff7a68.flac
#   inflating: train/28ebfe393.flac
#   inflating: train/28ed37c9a.flac
#   inflating: train/28fd95f7f.flac
#   inflating: train/2910b666b.flac
#   inflating: train/29127020a.flac
#   inflating: train/29164bc8d.flac
#   inflating: train/29179ab93.flac
#   inflating: train/29213ed4e.flac
#   inflating: train/29245287b.flac
#   inflating: train/292650843.flac
#   inflating: train/293139f99.flac
#   inflating: train/295f49a04.flac
#   inflating: train/298dd8876.flac
#   inflating: train/29a990e00.flac
#   inflating: train/29b82a129.flac
#   inflating: train/29ea8dc2c.flac
#   inflating: train/2a169cc41.flac
#   inflating: train/2a1924793.flac
#   inflating: train/2a1bb0557.flac
#   inflating: train/2a2dbd04d.flac
#   inflating: train/2a309fcdb.flac
#   inflating: train/2a3c1f921.flac
#   inflating: train/2a4230702.flac
#   inflating: train/2a55aed3a.flac
#   inflating: train/2a6694fce.flac
#   inflating: train/2a69408f6.flac
#   inflating: train/2a7255b0c.flac
#   inflating: train/2a730c98d.flac
#   inflating: train/2a7ed55d4.flac
#   inflating: train/2a94d4b86.flac
#   inflating: train/2abfa0e79.flac
#   inflating: train/2ad401356.flac
#   inflating: train/2ad9cad0e.flac
#   inflating: train/2adf71c95.flac
#   inflating: train/2ae54cd8e.flac
#   inflating: train/2b0618a23.flac
#   inflating: train/2b0d5706c.flac
#   inflating: train/2b1b234ce.flac
#   inflating: train/2b60aa72c.flac
#   inflating: train/2b9149a4b.flac
#   inflating: train/2b92d94b8.flac
#   inflating: train/2b9c8d234.flac
#   inflating: train/2b9cf13ef.flac
#   inflating: train/2ba4a4b2a.flac
#   inflating: train/2bb539997.flac
#   inflating: train/2bbe6a15f.flac
#   inflating: train/2bcddf9a5.flac
#   inflating: train/2bd964a10.flac
#   inflating: train/2bdde787f.flac
#   inflating: train/2be83e588.flac
#   inflating: train/2bf32cf03.flac
#   inflating: train/2c2127b9e.flac
#   inflating: train/2c29cdfb8.flac
#   inflating: train/2c4833148.flac
#   inflating: train/2c6ba715f.flac
#   inflating: train/2c6cd030a.flac
#   inflating: train/2c763167e.flac
#   inflating: train/2c77c2250.flac
#   inflating: train/2c8b3fa52.flac
#   inflating: train/2c97a8020.flac
#   inflating: train/2c9fc388d.flac
#   inflating: train/2cd094d21.flac
#   inflating: train/2cd09cfab.flac
#   inflating: train/2cd6722de.flac
#   inflating: train/2cda33945.flac
#   inflating: train/2ce34e1b6.flac
#   inflating: train/2ceab2a50.flac
#   inflating: train/2cf279c36.flac
#   inflating: train/2cf89ef6b.flac
#   inflating: train/2cff7e7b4.flac
#   inflating: train/2d09eb065.flac
#   inflating: train/2d0b599f2.flac
#   inflating: train/2d1d36b45.flac
#   inflating: train/2d4be0d32.flac
#   inflating: train/2d50db2b1.flac
#   inflating: train/2d6c6ddab.flac
#   inflating: train/2d775f3bf.flac
#   inflating: train/2d7d61a94.flac
#   inflating: train/2d7f18f82.flac
#   inflating: train/2d805f006.flac
#   inflating: train/2d81f8edf.flac
#   inflating: train/2dac8c2e2.flac
#   inflating: train/2dacf9479.flac
#   inflating: train/2db9c4705.flac
#   inflating: train/2dbde8233.flac
#   inflating: train/2dbfc6c8a.flac
#   inflating: train/2dc763e67.flac
#   inflating: train/2de2f19c2.flac
#   inflating: train/2df1f109b.flac
#   inflating: train/2df3efc0a.flac
#   inflating: train/2dfdea18c.flac
#   inflating: train/2dff25612.flac
#   inflating: train/2e1bf82ff.flac
#   inflating: train/2e1dca0df.flac
#   inflating: train/2e1ee378c.flac
#   inflating: train/2e3c703af.flac
#   inflating: train/2e40b2294.flac
#   inflating: train/2e6205ade.flac
#   inflating: train/2e6758f3e.flac
#   inflating: train/2e698aba5.flac
#   inflating: train/2e6d92e6e.flac
#   inflating: train/2e7bc0749.flac
#   inflating: train/2e9e82ed8.flac
#   inflating: train/2ea33531f.flac
#   inflating: train/2eab70582.flac
#   inflating: train/2eb098e76.flac
#   inflating: train/2ec1b3167.flac
#   inflating: train/2ed5af143.flac
#   inflating: train/2edb76a28.flac
#   inflating: train/2ef429016.flac
#   inflating: train/2ef55ba62.flac
#   inflating: train/2ef6800e7.flac
#   inflating: train/2f0ee87d7.flac
#   inflating: train/2f11a8c05.flac
#   inflating: train/2f1c2dc2d.flac
#   inflating: train/2f40810b2.flac
#   inflating: train/2f4514532.flac
#   inflating: train/2f471452d.flac
#   inflating: train/2f594b20f.flac
#   inflating: train/2f5d0583e.flac
#   inflating: train/2f659c4a3.flac
#   inflating: train/2f84e4ab6.flac
#   inflating: train/2f9846d0b.flac
#   inflating: train/2fa789928.flac
#   inflating: train/2faacd5e0.flac
#   inflating: train/2fc071891.flac
#   inflating: train/2fc2eca0c.flac
#   inflating: train/2fcfbcbdc.flac
#   inflating: train/2fe00fdac.flac
#   inflating: train/2fe8e5519.flac
#   inflating: train/2febbdfc5.flac
#   inflating: train/2ffaa6c02.flac
#   inflating: train/30095c4fe.flac
#   inflating: train/304141997.flac
#   inflating: train/30465b168.flac
#   inflating: train/304b4b5fd.flac
#   inflating: train/3051fc9d0.flac
#   inflating: train/305312c73.flac
#   inflating: train/305ff00d1.flac
#   inflating: train/3064b6276.flac
#   inflating: train/306c7f7f9.flac
#   inflating: train/306f98294.flac
#   inflating: train/3078884e8.flac
#   inflating: train/309517264.flac
#   inflating: train/30a1defc2.flac
#   inflating: train/30c4c7522.flac
#   inflating: train/30cd416ed.flac
#   inflating: train/30ef6469d.flac
#   inflating: train/30f186665.flac
#   inflating: train/3101382bc.flac
#   inflating: train/311b9c118.flac
#   inflating: train/31259d9d5.flac
#   inflating: train/31298d8d7.flac
#   inflating: train/312d33753.flac
#   inflating: train/3131292b7.flac
#   inflating: train/314371312.flac
#   inflating: train/314abd684.flac
#   inflating: train/315c434d0.flac
#   inflating: train/31635c86c.flac
#   inflating: train/3181f8112.flac
#   inflating: train/318fb828a.flac
#   inflating: train/3199eec22.flac
#   inflating: train/319e88027.flac
#   inflating: train/31ab84223.flac
#   inflating: train/31d654f96.flac
#   inflating: train/31e0e5b91.flac
#   inflating: train/31e4b7dc8.flac
#   inflating: train/31eb94279.flac
#   inflating: train/321c09a90.flac
#   inflating: train/32266c978.flac
#   inflating: train/32278292a.flac
#   inflating: train/32326a03d.flac
#   inflating: train/32464c219.flac
#   inflating: train/3267e79e6.flac
#   inflating: train/326992b55.flac
#   inflating: train/3292bbae4.flac
#   inflating: train/3296a3827.flac
#   inflating: train/32af58c85.flac
#   inflating: train/32c0ebf77.flac
#   inflating: train/32cf84e6f.flac
#   inflating: train/32e42c4fb.flac
#   inflating: train/32ea5e03e.flac
#   inflating: train/32f8c551e.flac
#   inflating: train/3346f84ee.flac
#   inflating: train/338107119.flac
#   inflating: train/338184e49.flac
#   inflating: train/338d8ea2e.flac
#   inflating: train/33c49049b.flac
#   inflating: train/33d0f2685.flac
#   inflating: train/33d5aebae.flac
#   inflating: train/33d925d83.flac
#   inflating: train/33dfe0a08.flac
#   inflating: train/340c7f964.flac
#   inflating: train/3413dd60b.flac
#   inflating: train/34340b225.flac
#   inflating: train/3447ebcd4.flac
#   inflating: train/344984de2.flac
#   inflating: train/3458e20b8.flac
#   inflating: train/346b22fb5.flac
#   inflating: train/3483217ab.flac
#   inflating: train/348e3f6db.flac
#   inflating: train/349095631.flac
#   inflating: train/349326260.flac
#   inflating: train/34967e1bb.flac
#   inflating: train/34b4e6080.flac
#   inflating: train/34beed6fe.flac
#   inflating: train/34ccdfe77.flac
#   inflating: train/34e6d5210.flac
#   inflating: train/3508bf762.flac
#   inflating: train/3513db2b8.flac
#   inflating: train/351466c48.flac
#   inflating: train/352056163.flac
#   inflating: train/3523d5f6a.flac
#   inflating: train/352a7358d.flac
#   inflating: train/352bc8d36.flac
#   inflating: train/3536ae520.flac
#   inflating: train/35596e9bf.flac
#   inflating: train/355ab6993.flac
#   inflating: train/35613e04e.flac
#   inflating: train/35675af70.flac
#   inflating: train/356b93991.flac
#   inflating: train/356fd5b86.flac
#   inflating: train/35844fa7f.flac
#   inflating: train/35a0342b2.flac
#   inflating: train/35a0c7254.flac
#   inflating: train/35a6e0f7e.flac
#   inflating: train/35a7c2277.flac
#   inflating: train/35b60a4a0.flac
#   inflating: train/35bfceac7.flac
#   inflating: train/35cc7e29e.flac
#   inflating: train/35f9c5c38.flac
#   inflating: train/35ff91122.flac
#   inflating: train/36002c100.flac
#   inflating: train/360394e69.flac
#   inflating: train/3626bd8db.flac
#   inflating: train/362f353f4.flac
#   inflating: train/3639adf40.flac
#   inflating: train/3641f60b7.flac
#   inflating: train/36460b230.flac
#   inflating: train/3647cd276.flac
#   inflating: train/364e10d4b.flac
#   inflating: train/364e9b5e7.flac
#   inflating: train/366fad396.flac
#   inflating: train/368bc8c14.flac
#   inflating: train/368be0579.flac
#   inflating: train/3696e276b.flac
#   inflating: train/36cdb6468.flac
#   inflating: train/36d97af66.flac
#   inflating: train/36d995c55.flac
#   inflating: train/3706b60bc.flac
#   inflating: train/3710abba6.flac
#   inflating: train/371ef3886.flac
#   inflating: train/372a21fa4.flac
#   inflating: train/373ec0df1.flac
#   inflating: train/373f470c4.flac
#   inflating: train/375ad7536.flac
#   inflating: train/3767dc5a5.flac
#   inflating: train/376a0a779.flac
#   inflating: train/377e04f82.flac
#   inflating: train/379838771.flac
#   inflating: train/37b6d1db9.flac
#   inflating: train/37c4a6c06.flac
#   inflating: train/37c91fbed.flac
#   inflating: train/37d16f30f.flac
#   inflating: train/37e7bb32e.flac
#   inflating: train/37e8f76ab.flac
#   inflating: train/37f670990.flac
#   inflating: train/382a24849.flac
#   inflating: train/382f74319.flac
#   inflating: train/3853bba8e.flac
#   inflating: train/38709fece.flac
#   inflating: train/387a431bc.flac
#   inflating: train/3889ed72c.flac
#   inflating: train/38bbedd15.flac
#   inflating: train/38c1d46ef.flac
#   inflating: train/38e65e173.flac
#   inflating: train/39093c2f2.flac
#   inflating: train/391674704.flac
#   inflating: train/39361b1ea.flac
#   inflating: train/396598a81.flac
#   inflating: train/396642b2f.flac
#   inflating: train/397e7eaa0.flac
#   inflating: train/39864d8ba.flac
#   inflating: train/398d2c4f1.flac
#   inflating: train/398e818ec.flac
#   inflating: train/399e17911.flac
#   inflating: train/39a6b288d.flac
#   inflating: train/39aa6482e.flac
#   inflating: train/39c15e092.flac
#   inflating: train/39c377007.flac
#   inflating: train/39e58073a.flac
#   inflating: train/39f6407f6.flac
#   inflating: train/3a1293df5.flac
#   inflating: train/3a2afcf76.flac
#   inflating: train/3a2b59426.flac
#   inflating: train/3a3848189.flac
#   inflating: train/3a49a2e6e.flac
#   inflating: train/3a55f66eb.flac
#   inflating: train/3a6637fb8.flac
#   inflating: train/3a819596b.flac
#   inflating: train/3a869dd99.flac
#   inflating: train/3a95606d7.flac
#   inflating: train/3aa730d19.flac
#   inflating: train/3aae54bad.flac
#   inflating: train/3ab39acdc.flac
#   inflating: train/3ab980f2d.flac
#   inflating: train/3abb75faf.flac
#   inflating: train/3ac6f246a.flac
#   inflating: train/3afd4fdb9.flac
#   inflating: train/3aff72a67.flac
#   inflating: train/3b0141c04.flac
#   inflating: train/3b064b25a.flac
#   inflating: train/3b0bbd1da.flac
#   inflating: train/3b0e345fc.flac
#   inflating: train/3b25a3af1.flac
#   inflating: train/3b46a50d0.flac
#   inflating: train/3b4c751d3.flac
#   inflating: train/3b5037d3e.flac
#   inflating: train/3b52710c1.flac
#   inflating: train/3b5d36adb.flac
#   inflating: train/3b7d51ee2.flac
#   inflating: train/3b83c6041.flac
#   inflating: train/3b8eb6094.flac
#   inflating: train/3ba822205.flac
#   inflating: train/3bb222791.flac
#   inflating: train/3c1e77d9f.flac
#   inflating: train/3c288364b.flac
#   inflating: train/3c293ebf8.flac
#   inflating: train/3c3dacbc2.flac
#   inflating: train/3c3ee86ab.flac
#   inflating: train/3c443fa6e.flac
#   inflating: train/3c48834c4.flac
#   inflating: train/3c48d80aa.flac
#   inflating: train/3c4cf66fd.flac
#   inflating: train/3c5d6f23a.flac
#   inflating: train/3c621e663.flac
#   inflating: train/3c65dc905.flac
#   inflating: train/3c75ea79b.flac
#   inflating: train/3c766c3c8.flac
#   inflating: train/3c84c103a.flac
#   inflating: train/3ca3a1b6a.flac
#   inflating: train/3cb221dbd.flac
#   inflating: train/3cbb2848e.flac
#   inflating: train/3cdd3f25f.flac
#   inflating: train/3ce447771.flac
#   inflating: train/3cf0187e0.flac
#   inflating: train/3d19d7bb0.flac
#   inflating: train/3d28b6a6b.flac
#   inflating: train/3d2b1c860.flac
#   inflating: train/3d2e3c306.flac
#   inflating: train/3d3d8bb00.flac
#   inflating: train/3d44b0b74.flac
#   inflating: train/3d4ad27d4.flac
#   inflating: train/3d63d443b.flac
#   inflating: train/3d6659ada.flac
#   inflating: train/3d7a0cbcc.flac
#   inflating: train/3da048f8e.flac
#   inflating: train/3da9950ab.flac
#   inflating: train/3dbfc4e5c.flac
#   inflating: train/3dc230571.flac
#   inflating: train/3dc4403e4.flac
#   inflating: train/3dee51126.flac
#   inflating: train/3e0e344a8.flac
#   inflating: train/3e422c029.flac
#   inflating: train/3e59ab985.flac
#   inflating: train/3e6f5c9b5.flac
#   inflating: train/3e9e4a349.flac
#   inflating: train/3ea1f54e9.flac
#   inflating: train/3ebc2aebe.flac
#   inflating: train/3ec09f8bc.flac
#   inflating: train/3eea13716.flac
#   inflating: train/3f002c337.flac
#   inflating: train/3f010282e.flac
#   inflating: train/3f04a523f.flac
#   inflating: train/3f056b3d1.flac
#   inflating: train/3f0f6e73d.flac
#   inflating: train/3f177b6cc.flac
#   inflating: train/3f19ff147.flac
#   inflating: train/3f3c49ad2.flac
#   inflating: train/3f3cad625.flac
#   inflating: train/3f4816f3a.flac
#   inflating: train/3f48c15dc.flac
#   inflating: train/3f5f4aa9a.flac
#   inflating: train/3f5fa0d76.flac
#   inflating: train/3f88e7718.flac
#   inflating: train/3f8b136ae.flac
#   inflating: train/3fa666880.flac
#   inflating: train/3fbde2a1f.flac
#   inflating: train/3fcca1372.flac
#   inflating: train/3fcead61b.flac
#   inflating: train/3fda65ce8.flac
#   inflating: train/3fe0369b8.flac
#   inflating: train/3fea75045.flac
#   inflating: train/3ffaeaa6c.flac
#   inflating: train/4002de600.flac
#   inflating: train/400b7210c.flac
#   inflating: train/403418175.flac
#   inflating: train/4037ecd74.flac
#   inflating: train/403df7c86.flac
#   inflating: train/404fa2c71.flac
#   inflating: train/4071f7aa7.flac
#   inflating: train/408314767.flac
#   inflating: train/408572e66.flac
#   inflating: train/408881af2.flac
#   inflating: train/408fcd1dc.flac
#   inflating: train/40cd85184.flac
#   inflating: train/40e97e435.flac
#   inflating: train/40f3d1306.flac
#   inflating: train/410af8433.flac
#   inflating: train/4113f2ba4.flac
#   inflating: train/413ac68c8.flac
#   inflating: train/413c1ab10.flac
#   inflating: train/414098e6e.flac
#   inflating: train/414a5da6e.flac
#   inflating: train/415cf2484.flac
#   inflating: train/416ab2797.flac
#   inflating: train/41712782c.flac
#   inflating: train/4173dbbaf.flac
#   inflating: train/417f43e5c.flac
#   inflating: train/41829d963.flac
#   inflating: train/419259ac2.flac
#   inflating: train/419abdc78.flac
#   inflating: train/419fb1a93.flac
#   inflating: train/41a0e0f9e.flac
#   inflating: train/41af7b890.flac
#   inflating: train/41c1f53c5.flac
#   inflating: train/41c70b0f1.flac
#   inflating: train/41d515379.flac
#   inflating: train/41e6d9f63.flac
#   inflating: train/420aeb3ea.flac
#   inflating: train/4216f7492.flac
#   inflating: train/421c20bdc.flac
#   inflating: train/421f9575b.flac
#   inflating: train/4229f3787.flac
#   inflating: train/422cd890c.flac
#   inflating: train/422de4e4d.flac
#   inflating: train/4238ed364.flac
#   inflating: train/425656a9b.flac
#   inflating: train/4261df85b.flac
#   inflating: train/426700103.flac
#   inflating: train/426c11508.flac
#   inflating: train/427069fef.flac
#   inflating: train/427d1a943.flac
#   inflating: train/4284af850.flac
#   inflating: train/428dae65f.flac
#   inflating: train/42a7c4f08.flac
#   inflating: train/42b240c98.flac
#   inflating: train/42b51edce.flac
#   inflating: train/42cfdbd16.flac
#   inflating: train/42d04eecf.flac
#   inflating: train/42e532195.flac
#   inflating: train/42e58f2ae.flac
#   inflating: train/42ea7a091.flac
#   inflating: train/42f483cb5.flac
#   inflating: train/42f4b8b64.flac
#   inflating: train/43092267f.flac
#   inflating: train/431c85554.flac
#   inflating: train/4325f1f4e.flac
#   inflating: train/432e2e899.flac
#   inflating: train/4332c54dc.flac
#   inflating: train/433f3a83f.flac
#   inflating: train/43423d1e3.flac
#   inflating: train/4344094dc.flac
#   inflating: train/436e875aa.flac
#   inflating: train/4373930a5.flac
#   inflating: train/43739e7ab.flac
#   inflating: train/437975e83.flac
#   inflating: train/437cab912.flac
#   inflating: train/4381af1a9.flac
#   inflating: train/438832119.flac
#   inflating: train/438c12dbc.flac
#   inflating: train/43b27b5ab.flac
#   inflating: train/43b921322.flac
#   inflating: train/43befeb3e.flac
#   inflating: train/43d34d63c.flac
#   inflating: train/43d64f73d.flac
#   inflating: train/43ee2cd2d.flac
#   inflating: train/43fee64b4.flac
#   inflating: train/4406d279c.flac
#   inflating: train/440d8589f.flac
#   inflating: train/44100c5d1.flac
#   inflating: train/441707582.flac
#   inflating: train/441f3196f.flac
#   inflating: train/442e648c3.flac
#   inflating: train/444ff0bad.flac
#   inflating: train/447409a6b.flac
# ...
#   inflating: train/e9926ec3e.flac
#   inflating: train/e99374851.flac
#   inflating: train/e9a873a03.flac
#   inflating: train/e9bab320a.flac
#   inflating: train/e9eb6d4dd.flac
#   inflating: train/e9ebe3979.flac
#   inflating: train/e9fa364b7.flac
#   inflating: train/ea03652c6.flac
#   inflating: train/ea133d03e.flac
#   inflating: train/ea26b19ee.flac
#   inflating: train/ea394632e.flac
#   inflating: train/ea4cfd7bb.flac
#   inflating: train/ea544e255.flac
#   inflating: train/ea54f137c.flac
#   inflating: train/ea5620da7.flac
#   inflating: train/ea5db20f4.flac
#   inflating: train/ea71a1a7d.flac
#   inflating: train/ea7aa9e69.flac
#   inflating: train/ea7b61120.flac
#   inflating: train/ea7da0899.flac
#   inflating: train/ea961733c.flac
#   inflating: train/ea9cca0b6.flac
#   inflating: train/eaaa6085c.flac
#   inflating: train/eaad51fc0.flac
#   inflating: train/eab360d90.flac
#   inflating: train/eac4c4220.flac
#   inflating: train/eacd010a3.flac
#   inflating: train/eadccba2d.flac
#   inflating: train/eae60f3c2.flac
#   inflating: train/eae772c6f.flac
#   inflating: train/eaec531d1.flac
#   inflating: train/eaf5cf482.flac
#   inflating: train/eaff98615.flac
#   inflating: train/eb0cd97da.flac
#   inflating: train/eb1663b0c.flac
#   inflating: train/eb3081e46.flac
#   inflating: train/eb3145e54.flac
#   inflating: train/eb50c4520.flac
#   inflating: train/eb54756a0.flac
#   inflating: train/eb62e367c.flac
#   inflating: train/eb685f870.flac
#   inflating: train/eb6e0f54a.flac
#   inflating: train/eb834b94f.flac
#   inflating: train/ebb21fb4d.flac
#   inflating: train/ebdd7c181.flac
#   inflating: train/ebeb631d2.flac
#   inflating: train/ebf117ba6.flac
#   inflating: train/ebf2db488.flac
#   inflating: train/ec02f75ce.flac
#   inflating: train/ec098238c.flac
#   inflating: train/ec0dad95d.flac
#   inflating: train/ec1255787.flac
#   inflating: train/ec163af80.flac
#   inflating: train/ec1c4a754.flac
#   inflating: train/ec24a4d07.flac
#   inflating: train/ec2feba84.flac
#   inflating: train/ec3a54dc6.flac
#   inflating: train/ec437e081.flac
#   inflating: train/ec56c2ee5.flac
#   inflating: train/ec5bfe219.flac
#   inflating: train/ec5e26845.flac
#   inflating: train/ec63de3ab.flac
#   inflating: train/ec776fd7b.flac
#   inflating: train/ec808f26f.flac
#   inflating: train/ec8c30dd9.flac
#   inflating: train/ec8cda160.flac
#   inflating: train/eca5caddc.flac
#   inflating: train/eca614521.flac
#   inflating: train/eca7db529.flac
#   inflating: train/ecb326f94.flac
#   inflating: train/ecca11208.flac
#   inflating: train/eccdd4ea8.flac
#   inflating: train/ecd47f7cc.flac
#   inflating: train/ecda926b6.flac
#   inflating: train/ecf502215.flac
#   inflating: train/ed10a157a.flac
#   inflating: train/ed2ae7025.flac
#   inflating: train/ed2ce7b96.flac
#   inflating: train/ed2f84e75.flac
#   inflating: train/ed36faac8.flac
#   inflating: train/ed38c48b8.flac
#   inflating: train/ed3c557ff.flac
#   inflating: train/ed5627ec7.flac
#   inflating: train/ed74416d3.flac
#   inflating: train/ed82ecb39.flac
#   inflating: train/ed8b65c55.flac
#   inflating: train/ed92f0516.flac
#   inflating: train/ed9376d01.flac
#   inflating: train/eda207f9f.flac
#   inflating: train/eda9452aa.flac
#   inflating: train/edc38715d.flac
#   inflating: train/edcb36c64.flac
#   inflating: train/edccfd690.flac
#   inflating: train/edcdb1df0.flac
#   inflating: train/edd3b27d6.flac
#   inflating: train/edd568403.flac
#   inflating: train/edf598655.flac
#   inflating: train/edf85ed18.flac
#   inflating: train/edf9fe22d.flac
#   inflating: train/ee3dc0bc6.flac
#   inflating: train/ee3eab224.flac
#   inflating: train/ee694343e.flac
#   inflating: train/ee80e2415.flac
#   inflating: train/ee8e42ab9.flac
#   inflating: train/ee922d946.flac
#   inflating: train/ee95a6aa4.flac
#   inflating: train/eeb9a3c4b.flac
#   inflating: train/eec8513cf.flac
#   inflating: train/eeca58840.flac
#   inflating: train/eee00469a.flac
#   inflating: train/eef94938d.flac
#   inflating: train/eefd05610.flac
#   inflating: train/ef069cab5.flac
#   inflating: train/ef07a65a3.flac
#   inflating: train/ef0aaa0b3.flac
#   inflating: train/ef0dffdab.flac
#   inflating: train/ef0faf6e4.flac
#   inflating: train/ef10f60bf.flac
#   inflating: train/ef1d98fff.flac
#   inflating: train/ef21b29bc.flac
#   inflating: train/ef3647390.flac
#   inflating: train/ef40c1067.flac
#   inflating: train/ef47304a3.flac
#   inflating: train/ef5494785.flac
#   inflating: train/ef6183d31.flac
#   inflating: train/ef6cfb9fa.flac
#   inflating: train/ef932de8e.flac
#   inflating: train/ef95a6efe.flac
#   inflating: train/ef9af2faf.flac
#   inflating: train/efb6a2e01.flac
#   inflating: train/efbfe6b39.flac
#   inflating: train/efcc3bd16.flac
#   inflating: train/efd9010ba.flac
#   inflating: train/efe937284.flac
#   inflating: train/f000113e5.flac
#   inflating: train/f003fb7c6.flac
#   inflating: train/f01a344c4.flac
#   inflating: train/f021c411a.flac
#   inflating: train/f0298d1fe.flac
#   inflating: train/f034ac58b.flac
#   inflating: train/f0356d3da.flac
#   inflating: train/f052aee74.flac
#   inflating: train/f056ec3e8.flac
#   inflating: train/f07768518.flac
#   inflating: train/f09f9e7ba.flac
#   inflating: train/f0ae3ff46.flac
#   inflating: train/f0d8ebc52.flac
#   inflating: train/f0e65ccad.flac
#   inflating: train/f0f4fcc74.flac
#   inflating: train/f109f8584.flac
#   inflating: train/f1273a1ca.flac
#   inflating: train/f12753fce.flac
#   inflating: train/f131c8078.flac
#   inflating: train/f152e26e3.flac
#   inflating: train/f15dd21b5.flac
#   inflating: train/f16860025.flac
#   inflating: train/f19c335eb.flac
#   inflating: train/f1a76479e.flac
#   inflating: train/f1aa1c855.flac
#   inflating: train/f1b7d8c75.flac
#   inflating: train/f1be0a6f7.flac
#   inflating: train/f1cc7d0a4.flac
#   inflating: train/f1ccee878.flac
#   inflating: train/f1de9d996.flac
#   inflating: train/f1e073656.flac
#   inflating: train/f1e9b206b.flac
#   inflating: train/f1ea78f27.flac
#   inflating: train/f1ecfb2df.flac
#   inflating: train/f1fc4f439.flac
#   inflating: train/f241314bb.flac
#   inflating: train/f2446546b.flac
#   inflating: train/f2493eda1.flac
#   inflating: train/f254ccc4e.flac
#   inflating: train/f25a5f303.flac
#   inflating: train/f278c5f5c.flac
#   inflating: train/f28530d94.flac
#   inflating: train/f2890653e.flac
#   inflating: train/f2be3bea8.flac
#   inflating: train/f2c07ab40.flac
#   inflating: train/f2c52223a.flac
#   inflating: train/f2d7b8ed8.flac
#   inflating: train/f2d7ff608.flac
#   inflating: train/f2d986715.flac
#   inflating: train/f2dbe3dc3.flac
#   inflating: train/f2dfb1141.flac
#   inflating: train/f313f236e.flac
#   inflating: train/f32a8c8f0.flac
#   inflating: train/f33a1793f.flac
#   inflating: train/f33f1761c.flac
#   inflating: train/f35bc1452.flac
#   inflating: train/f36d01ed2.flac
#   inflating: train/f38a15500.flac
#   inflating: train/f3a0a4c50.flac
#   inflating: train/f3a38df5f.flac
#   inflating: train/f3a76f283.flac
#   inflating: train/f3abe6053.flac
#   inflating: train/f3b79a9d6.flac
#   inflating: train/f3b84afb1.flac
#   inflating: train/f3bebfb56.flac
#   inflating: train/f3cb40395.flac
#   inflating: train/f3df14ff5.flac
#   inflating: train/f3ed4434b.flac
#   inflating: train/f3f146f8e.flac
#   inflating: train/f3f42968a.flac
#   inflating: train/f3f813801.flac
#   inflating: train/f3f82b897.flac
#   inflating: train/f3fa23916.flac
#   inflating: train/f470e45e5.flac
#   inflating: train/f4714d970.flac
#   inflating: train/f479ea4be.flac
#   inflating: train/f49040624.flac
#   inflating: train/f49a804e8.flac
#   inflating: train/f4a8d9893.flac
#   inflating: train/f4bd598f8.flac
#   inflating: train/f4c73df68.flac
#   inflating: train/f4c78a256.flac
#   inflating: train/f4d05c0de.flac
#   inflating: train/f4dd82c85.flac
#   inflating: train/f4ea15de9.flac
#   inflating: train/f4f758958.flac
#   inflating: train/f5052f12e.flac
#   inflating: train/f5087f6e9.flac
#   inflating: train/f51109a9b.flac
#   inflating: train/f51c0da28.flac
#   inflating: train/f5226c724.flac
#   inflating: train/f536a7f8f.flac
#   inflating: train/f537b2b72.flac
#   inflating: train/f5427b3c3.flac
#   inflating: train/f543f0d31.flac
#   inflating: train/f554e875b.flac
#   inflating: train/f55ce9e53.flac
#   inflating: train/f563c666c.flac
#   inflating: train/f5790385e.flac
#   inflating: train/f57ffd248.flac
#   inflating: train/f5889157c.flac
#   inflating: train/f58e7830a.flac
#   inflating: train/f59a76d40.flac
#   inflating: train/f5c3420f6.flac
#   inflating: train/f5da0eae7.flac
#   inflating: train/f5e6456f0.flac
#   inflating: train/f5f952b6b.flac
#   inflating: train/f6198f866.flac
#   inflating: train/f61b72beb.flac
#   inflating: train/f6202c64d.flac
#   inflating: train/f638038ca.flac
#   inflating: train/f63878d52.flac
#   inflating: train/f63c7ca2f.flac
#   inflating: train/f64cfa023.flac
#   inflating: train/f65cdcd99.flac
#   inflating: train/f66510877.flac
#   inflating: train/f66ddce4b.flac
#   inflating: train/f6789d4ac.flac
#   inflating: train/f67c63745.flac
#   inflating: train/f68c23276.flac
#   inflating: train/f69116f77.flac
#   inflating: train/f6b50aeb1.flac
#   inflating: train/f6cbc01c7.flac
#   inflating: train/f6e41b038.flac
#   inflating: train/f702f163c.flac
#   inflating: train/f737f18dc.flac
#   inflating: train/f73939fb9.flac
#   inflating: train/f73bc3666.flac
#   inflating: train/f7466aeeb.flac
#   inflating: train/f76471a24.flac
#   inflating: train/f7a7ae678.flac
#   inflating: train/f7abca965.flac
#   inflating: train/f7bb163d8.flac
#   inflating: train/f7c93a6a8.flac
#   inflating: train/f7cf8e342.flac
#   inflating: train/f7d3b0080.flac
#   inflating: train/f7d92975f.flac
#   inflating: train/f7edb8a8c.flac
#   inflating: train/f7f3548f4.flac
#   inflating: train/f806be4f5.flac
#   inflating: train/f807ee90e.flac
#   inflating: train/f827a8428.flac
#   inflating: train/f829230cd.flac
#   inflating: train/f84b8c8d3.flac
#   inflating: train/f84d77b83.flac
#   inflating: train/f851b0095.flac
#   inflating: train/f851b9605.flac
#   inflating: train/f86e7752e.flac
#   inflating: train/f879b8abf.flac
#   inflating: train/f87ef432d.flac
#   inflating: train/f885c0336.flac
#   inflating: train/f8c661973.flac
#   inflating: train/f8cb4f59b.flac
#   inflating: train/f8e231afe.flac
#   inflating: train/f90377f8f.flac
#   inflating: train/f91be322f.flac
#   inflating: train/f93111a02.flac
#   inflating: train/f934516a8.flac
#   inflating: train/f93a90649.flac
#   inflating: train/f955ef2d0.flac
#   inflating: train/f95b2ec2d.flac
#   inflating: train/f9758f56e.flac
#   inflating: train/f97ababc1.flac
#   inflating: train/f97caec7c.flac
#   inflating: train/f986b8a4d.flac
#   inflating: train/f9b59f987.flac
#   inflating: train/f9bab6d86.flac
#   inflating: train/f9dad91d4.flac
#   inflating: train/f9e3b11ad.flac
#   inflating: train/f9e724b46.flac
#   inflating: train/f9f2bfa12.flac
#   inflating: train/fa0be0407.flac
#   inflating: train/fa0eee1e4.flac
#   inflating: train/fa1776098.flac
#   inflating: train/fa17d8cb6.flac
#   inflating: train/fa1fb2e42.flac
#   inflating: train/fa27b0f5f.flac
#   inflating: train/fa33806dd.flac
#   inflating: train/fa37133a9.flac
#   inflating: train/fa4e32383.flac
#   inflating: train/fa5242384.flac
#   inflating: train/fa5c16880.flac
#   inflating: train/fa9353c0a.flac
#   inflating: train/fa9513274.flac
#   inflating: train/fab2cbfa6.flac
#   inflating: train/faca6a380.flac
#   inflating: train/face9266f.flac
#   inflating: train/fad9def77.flac
#   inflating: train/fae58971a.flac
#   inflating: train/fae8f99f6.flac
#   inflating: train/fb01fdcea.flac
#   inflating: train/fb02b0607.flac
#   inflating: train/fb0abd176.flac
#   inflating: train/fb3725395.flac
#   inflating: train/fb384cbcd.flac
#   inflating: train/fb455d471.flac
#   inflating: train/fb5371e7b.flac
#   inflating: train/fb71ca02d.flac
#   inflating: train/fb7ab38bf.flac
#   inflating: train/fb7b96ee9.flac
#   inflating: train/fb819ab0d.flac
#   inflating: train/fb9c97afd.flac
#   inflating: train/fba461eab.flac
#   inflating: train/fba69b00a.flac
#   inflating: train/fbab42376.flac
#   inflating: train/fbb31daeb.flac
#   inflating: train/fbbca0c89.flac
#   inflating: train/fbd5bbb6e.flac
#   inflating: train/fc238d19c.flac
#   inflating: train/fc302ff12.flac
#   inflating: train/fc326c372.flac
#   inflating: train/fc41274ec.flac
#   inflating: train/fc47cfba3.flac
#   inflating: train/fc504202e.flac
#   inflating: train/fc6609050.flac
#   inflating: train/fc6c3b488.flac
#   inflating: train/fc8cbe35e.flac
#   inflating: train/fca4f8957.flac
#   inflating: train/fce4dd8fa.flac
#   inflating: train/fcea8888b.flac
#   inflating: train/fceda95a6.flac
#   inflating: train/fd1970634.flac
#   inflating: train/fd3199510.flac
#   inflating: train/fd32fec9c.flac
#   inflating: train/fd3c6a0fd.flac
#   inflating: train/fd3f0d49b.flac
#   inflating: train/fd59168d0.flac
#   inflating: train/fd5fdc0e5.flac
#   inflating: train/fd6a520d8.flac
#   inflating: train/fd71b9c9d.flac
#   inflating: train/fd7cc65e1.flac
#   inflating: train/fd923f5d5.flac
#   inflating: train/fd9b5e60d.flac
#   inflating: train/fda3f9c8b.flac
#   inflating: train/fdc2731e0.flac
#   inflating: train/fdc43dd19.flac
#   inflating: train/fdd917cf3.flac
#   inflating: train/fdda158ed.flac
#   inflating: train/fe085ae3d.flac
#   inflating: train/fe08621d5.flac
#   inflating: train/fe11fb99b.flac
#   inflating: train/fe2551532.flac
#   inflating: train/fe2ac79e2.flac
#   inflating: train/fe3c4378e.flac
#   inflating: train/fe679dc72.flac
#   inflating: train/fe754ef0d.flac
#   inflating: train/fe7cd221a.flac
#   inflating: train/fe83b6421.flac
#   inflating: train/fe8ce67c3.flac
#   inflating: train/fe8d9ac40.flac
#   inflating: train/fe8f47d1e.flac
#   inflating: train/fea6b438a.flac
#   inflating: train/feb4d67f1.flac
#   inflating: train/fec53d619.flac
#   inflating: train/fec727570.flac
#   inflating: train/fed5d1b9c.flac
#   inflating: train/ff10ca044.flac
#   inflating: train/ff12e3126.flac
#   inflating: train/ff1fb7569.flac
#   inflating: train/ff21001e6.flac
#   inflating: train/ff22519ea.flac
#   inflating: train/ff255b11a.flac
#   inflating: train/ff2eb9ce5.flac
#   inflating: train/ff4b91c72.flac
#   inflating: train/ff543712f.flac
#   inflating: train/ff54c37c8.flac
#   inflating: train/ff56888a1.flac
#   inflating: train/ff5c2d55f.flac
#   inflating: train/ff61d0146.flac
#   inflating: train/ff672e3bb.flac
#   inflating: train/ff6aa0e63.flac
#   inflating: train/ff6acf404.flac
#   inflating: train/ff6ba53d5.flac
#   inflating: train/ff7f876bd.flac
#   inflating: train/ff8492f71.flac
#   inflating: train/ff858780b.flac
#   inflating: train/ffaaa4c77.flac
#   inflating: train/ffb8d8391.flac
#   inflating: train/ffb9a7b9a.flac
#   inflating: train/ffc51b999.flac
#   inflating: train/ffc6031f8.flac
#   inflating: train/ffd88cd84.flac
#   inflating: train/ffebe7313.flac
#   inflating: train/fff163132.flac
#   inflating: train/fffb79246.flac
#   inflating: train/_fp.csv
#   inflating: train/_tp.csv

# %%
! pip install -q tensorflow-io
# Out:
#      |████████████████████████████████| 25.3MB 138kB/s

# %% [markdown]
# ## 1. Importing necessary libraries

# %%
import tensorflow as tf
import numpy as np 
import tensorflow_io as tfio
import pandas as pd
from datetime import datetime,timedelta
import os

# %%
# Loading the dataset 
train = pd.read_csv('/content/drive/MyDrive/CS2/train_tp.csv')
train
# Out:
#      recording_id  species_id  songtype_id  ...     f_min    t_max     f_max
# 0       003bec244          14            1  ...  2531.250  45.1307   5531.25
# 1       006ab765f          23            1  ...  7235.160  46.0452  11283.40
# 2       007f87ba2          12            1  ...   562.500  42.2720   3281.25
# 3       0099c367b          17            4  ...  1464.260  55.1996   4565.04
# 4       009b760e6          10            1  ...   947.461  52.5293  10852.70
# ...           ...         ...          ...  ...       ...      ...       ...
# 1211    fe8d9ac40          13            1  ...    93.750  54.0960    843.75
# 1212    fea6b438a           4            1  ...  2531.250  45.7653   4031.25
# 1213    ff2eb9ce5           0            1  ...  5906.250  16.0213   8250.00
# 1214    ffb8d8391           5            1  ...  4781.250  16.6987  10406.20
# 1215    ffb9a7b9a          18            1  ...  3187.500  41.0133   5062.50
#
# [1216 rows x 7 columns]

# %% [markdown]
# ## 2. Defining the functions

# %%
def final_fun_unquantized(file):
    # Saving the starting time
    start1 = datetime.now()

    # Creating mel-spectrogram
    audio = tfio.audio.AudioIOTensor('train/'+file['recording_id']+'.flac')
    audio_slice = audio[100:]

    # remove last dimension
    audio_tensor = tf.squeeze(audio_slice, axis=[-1])
    audio_tensor = tf.cast(audio_tensor, tf.float32)

    # Convert to spectrogram
    spectrogram = tfio.experimental.audio.spectrogram(audio_tensor, nfft=2048, window=2048, stride=512)

    # Convert to mel-spectrogram
    mel_spectrogram = tfio.experimental.audio.melscale(spectrogram, rate=48000, mels=384, fmin=40, fmax=24000)

    # Convert to db scale mel-spectrogram
    mel_spectrogram = tfio.experimental.audio.dbscale(mel_spectrogram, top_db=80)

    # Expanding the dimensions of spectrograms by 1 
    image = tf.expand_dims(mel_spectrogram, axis= -1)
    # Resizing the spectrogram
    image = tf.image.resize(image, [384, 768])
    # Converting the spectrogram to rgb
    image = tf.image.grayscale_to_rgb(image)
    # Expanding the dims for input data
    image = tf.expand_dims(image,axis = 0)

    start2 = datetime.now()
    # Creating the model
    backbone = tf.keras.applications.DenseNet121(include_top = False,input_shape = (384,768,3), weights="imagenet")

    for layer in backbone.layers[:0]:
        layer.trainable = False

    model = tf.keras.Sequential([
                backbone,
                tf.keras.layers.GlobalAveragePooling2D(),
                tf.keras.layers.Dense(128, activation='relu', kernel_initializer=tf.keras.initializers.he_normal()),
                tf.keras.layers.Dropout(0.3),
                tf.keras.layers.BatchNormalization(),
                tf.keras.layers.Dense(24,bias_initializer=tf.keras.initializers.Constant(-2.))])
    
    # Loading the model weights and predicting the ouput
    model.load_weights('/content/drive/MyDrive/CS2/Models/Saved_model.h5')
    output = tf.sigmoid(model(image)).numpy()

    # Printing the time taken 
    end = datetime.now()
    print('Time taken to load the model and predict the value :',end - start2) 
    print('Time taken including preprocessing the audio files :',end - start1) 

    # Returning the output
    return output[0], (end - start1)

# %%
def final_fun_float16(file):
    # Saving the starting time
    start1 = datetime.now()

    # Creating mel-spectrogram
    audio = tfio.audio.AudioIOTensor('train/'+file['recording_id']+'.flac')
    audio_slice = audio[100:]

    # remove last dimension
    audio_tensor = tf.squeeze(audio_slice, axis=[-1])
    audio_tensor = tf.cast(audio_tensor, tf.float32)

    # Convert to spectrogram
    spectrogram = tfio.experimental.audio.spectrogram(audio_tensor, nfft=2048, window=2048, stride=512)

    # Convert to mel-spectrogram
    mel_spectrogram = tfio.experimental.audio.melscale(spectrogram, rate=48000, mels=384, fmin=40, fmax=24000)

    # Convert to db scale mel-spectrogram
    mel_spectrogram = tfio.experimental.audio.dbscale(mel_spectrogram, top_db=80)

    # Expanding the dimensions of spectrograms by 1 
    image = tf.expand_dims(mel_spectrogram, axis= -1)
    # Resizing the spectrogram
    image = tf.image.resize(image, [384, 768])
    # Converting the spectrogram to rgb
    image = tf.image.grayscale_to_rgb(image)
    # Expanding the dims for input data
    image = tf.expand_dims(image,axis = 0)

    start2 = datetime.now()
    # Load the TFLite model and allocate tensors.
    interpreter = tf.lite.Interpreter(model_path='/content/drive/MyDrive/CS2/Models/float16_quantization.tflite')
    interpreter.allocate_tensors()

    # Get input and output tensors.
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()

    interpreter.set_tensor(input_details[0]['index'], image)
    interpreter.invoke()

    # The function `get_tensor()` returns a copy of the tensor data.
    # Use `tensor()` in order to get a pointer to the tensor.
    pred = interpreter.get_tensor(output_details[0]['index'])
    output = tf.sigmoid(pred).numpy()

    # Printing the time taken 
    end = datetime.now()
    print('Time taken to load the model and predict the value :',end - start2) 
    print('Time taken including preprocessing the audio files :',end - start1) 

    return output[0], (end - start1)

# %%
def final_fun_dynamic(file):
    # Saving the starting time
    start1 = datetime.now()

    # Creating mel-spectrogram
    audio = tfio.audio.AudioIOTensor('train/'+file['recording_id']+'.flac')
    audio_slice = audio[100:]

    # remove last dimension
    audio_tensor = tf.squeeze(audio_slice, axis=[-1])
    audio_tensor = tf.cast(audio_tensor, tf.float32)

    # Convert to spectrogram
    spectrogram = tfio.experimental.audio.spectrogram(audio_tensor, nfft=2048, window=2048, stride=512)

    # Convert to mel-spectrogram
    mel_spectrogram = tfio.experimental.audio.melscale(spectrogram, rate=48000, mels=384, fmin=40, fmax=24000)

    # Convert to db scale mel-spectrogram
    mel_spectrogram = tfio.experimental.audio.dbscale(mel_spectrogram, top_db=80)

    # Expanding the dimensions of spectrograms by 1 
    image = tf.expand_dims(mel_spectrogram, axis= -1)
    # Resizing the spectrogram
    image = tf.image.resize(image, [384, 768])
    # Converting the spectrogram to rgb
    image = tf.image.grayscale_to_rgb(image)
    # Expanding the dims for input data
    image = tf.expand_dims(image,axis = 0)

    start2 = datetime.now()
    # Load the TFLite model and allocate tensors.
    interpreter = tf.lite.Interpreter(model_path='/content/drive/MyDrive/CS2/Models/dynamic_quantization.tflite')
    interpreter.allocate_tensors()

    # Get input and output tensors.
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()

    interpreter.set_tensor(input_details[0]['index'], image)
    interpreter.invoke()

    # The function `get_tensor()` returns a copy of the tensor data.
    # Use `tensor()` in order to get a pointer to the tensor.
    pred = interpreter.get_tensor(output_details[0]['index'])
    output = tf.sigmoid(pred).numpy()

    # Printing the time taken 
    end = datetime.now()
    print('Time taken to load the model and predict the value :',end - start2) 
    print('Time taken including preprocessing the audio files :',end - start1) 

    return output[0], (end - start1)

# %% [markdown]
# ## 3.1 Running on CPU

# %% [markdown]
# ### Unquantized model

# %%
with tf.device('/cpu:0'):
    time_list = [] 
    for i in range(5):
        index = np.random.randint(0,1216)
        val,time = final_fun_unquantized(train.iloc[index])
        print('actual value:', train.iloc[index]['species_id'])
        print('top 3 predicted values according to probabilities:', val.argsort()[-3:][::-1])
        print('-'*100)
        time_list.append(time)

    mysum = timedelta()
    for i in time_list:
        mysum += i
    print('Average time taken for prediction: ',str(mysum/5))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# Time taken to load the model and predict the value : 0:00:05.175729
# Time taken including preprocessing the audio files : 0:00:07.079130
# actual value: 14
# top 3 predicted values according to probabilities: [14 21  8]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:03.897237
# Time taken including preprocessing the audio files : 0:00:05.323181
# actual value: 18
# top 3 predicted values according to probabilities: [18  4 12]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:04.082207
# Time taken including preprocessing the audio files : 0:00:05.464689
# actual value: 17
# top 3 predicted values according to probabilities: [17 11 23]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:04.082971
# Time taken including preprocessing the audio files : 0:00:05.448595
# actual value: 23
# top 3 predicted values according to probabilities: [ 6  4 17]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:03.982301
# Time taken including preprocessing the audio files : 0:00:05.338820
# actual value: 3
# top 3 predicted values according to probabilities: [ 5 19  0]
# ----------------------------------------------------------------------------------------------------
# Average time taken for prediction:  0:00:05.730883

# %% [markdown]
# ### float16 quantized model

# %%
with tf.device('/cpu:0'):
    time_list = [] 
    for i in range(5):
        index = np.random.randint(0,1216)
        val,time = final_fun_float16(train.iloc[index])
        print('actual value:', train.iloc[index]['species_id'])
        print('top 3 predicted values according to probabilities:', val.argsort()[-3:][::-1])
        print('-'*100)
        time_list.append(time)

    mysum = timedelta()
    for i in time_list:
        mysum += i
    print('Average time taken for prediction: ',str(mysum/5))
# Out:
# Time taken to load the model and predict the value : 0:00:01.144907
# Time taken including preprocessing the audio files : 0:00:02.510704
# actual value: 22
# top 3 predicted values according to probabilities: [23 22  9]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:00.652231
# Time taken including preprocessing the audio files : 0:00:02.019836
# actual value: 18
# top 3 predicted values according to probabilities: [ 0 18  8]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:00.638172
# Time taken including preprocessing the audio files : 0:00:02.005120
# actual value: 3
# top 3 predicted values according to probabilities: [2 3 0]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:00.631317
# Time taken including preprocessing the audio files : 0:00:01.987089
# actual value: 19
# top 3 predicted values according to probabilities: [ 6 17 19]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:00.652662
# Time taken including preprocessing the audio files : 0:00:02.018513
# actual value: 1
# top 3 predicted values according to probabilities: [ 1  3 16]
# ----------------------------------------------------------------------------------------------------
# Average time taken for prediction:  0:00:02.108252

# %% [markdown]
# ### Dynamic Quantized model

# %%
with tf.device('/cpu:0'):
    time_list = [] 
    for i in range(5):
        index = np.random.randint(0,1216)
        val,time = final_fun_dynamic(train.iloc[index])
        print('actual value:', train.iloc[index]['species_id'])
        print('top 3 predicted values according to probabilities:', val.argsort()[-3:][::-1])
        print('-'*100)
        time_list.append(time)

    mysum = timedelta()
    for i in time_list:
        mysum += i
    print('Average time taken for prediction: ',str(mysum/5))
# Out:
# Time taken to load the model and predict the value : 0:00:43.578719
# Time taken including preprocessing the audio files : 0:00:44.940260
# actual value: 11
# top 3 predicted values according to probabilities: [11  7  5]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:43.149642
# Time taken including preprocessing the audio files : 0:00:44.554716
# actual value: 21
# top 3 predicted values according to probabilities: [21  8  4]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:43.045146
# Time taken including preprocessing the audio files : 0:00:44.427445
# actual value: 20
# top 3 predicted values according to probabilities: [11 16  3]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:43.266109
# Time taken including preprocessing the audio files : 0:00:44.625532
# actual value: 11
# top 3 predicted values according to probabilities: [10 11  5]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:43.096415
# Time taken including preprocessing the audio files : 0:00:44.502454
# actual value: 10
# top 3 predicted values according to probabilities: [10  5 11]
# ----------------------------------------------------------------------------------------------------
# Average time taken for prediction:  0:00:44.610081

# %% [markdown]
# ## 3.2 Running on GPU

# %% [markdown]
# ### Unquantized model

# %%
with tf.device('/gpu:0'):
    time_list = [] 
    for i in range(5):
        index = np.random.randint(0,1216)
        val,time = final_fun_unquantized(train.iloc[index])
        print('actual value:', train.iloc[index]['species_id'])
        print('top 3 predicted values according to probabilities:', val.argsort()[-3:][::-1])
        print('-'*100)
        time_list.append(time)

    mysum = timedelta()
    for i in time_list:
        mysum += i
    print('Average time taken for prediction: ',str(mysum/5))
# Out:
# Time taken to load the model and predict the value : 0:00:09.089723
# Time taken including preprocessing the audio files : 0:00:11.896693
# actual value: 9
# top 3 predicted values according to probabilities: [23 12 18]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:03.562916
# Time taken including preprocessing the audio files : 0:00:03.673237
# actual value: 23
# top 3 predicted values according to probabilities: [11 20 23]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:03.413133
# Time taken including preprocessing the audio files : 0:00:03.513629
# actual value: 7
# top 3 predicted values according to probabilities: [15  7 18]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:03.669327
# Time taken including preprocessing the audio files : 0:00:03.760667
# actual value: 7
# top 3 predicted values according to probabilities: [ 7 15  3]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:03.710769
# Time taken including preprocessing the audio files : 0:00:03.819601
# actual value: 11
# top 3 predicted values according to probabilities: [11 10  5]
# ----------------------------------------------------------------------------------------------------
# Average time taken for prediction:  0:00:05.332765

# %% [markdown]
# ### float16 quantized model

# %%
with tf.device('/gpu:0'):
    time_list = [] 
    for i in range(5):
        index = np.random.randint(0,1216)
        val,time = final_fun_float16(train.iloc[index])
        print('actual value:', train.iloc[index]['species_id'])
        print('top 3 predicted values according to probabilities:', val.argsort()[-3:][::-1])
        print('-'*100)
        time_list.append(time)

    mysum = timedelta()
    for i in time_list:
        mysum += i
    print('Average time taken for prediction: ',str(mysum/5))
# Out:
# Time taken to load the model and predict the value : 0:00:00.711897
# Time taken including preprocessing the audio files : 0:00:00.839132
# actual value: 14
# top 3 predicted values according to probabilities: [14 21  8]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:00.654630
# Time taken including preprocessing the audio files : 0:00:00.764751
# actual value: 3
# top 3 predicted values according to probabilities: [16  3  7]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:00.647121
# Time taken including preprocessing the audio files : 0:00:00.744098
# actual value: 14
# top 3 predicted values according to probabilities: [14 21  1]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:00.647524
# Time taken including preprocessing the audio files : 0:00:00.744576
# actual value: 6
# top 3 predicted values according to probabilities: [11 20 17]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:00.654960
# Time taken including preprocessing the audio files : 0:00:00.755262
# actual value: 14
# top 3 predicted values according to probabilities: [14 21  1]
# ----------------------------------------------------------------------------------------------------
# Average time taken for prediction:  0:00:00.769564

# %% [markdown]
# ### Dynamic Quantized Model

# %%
with tf.device('/gpu:0'):
    time_list = [] 
    for i in range(5):
        index = np.random.randint(0,1216)
        val,time = final_fun_dynamic(train.iloc[index])
        print('actual value:', train.iloc[index]['species_id'])
        print('top 3 predicted values according to probabilities:', val.argsort()[-3:][::-1])
        print('-'*100)
        time_list.append(time)

    mysum = timedelta()
    for i in time_list:
        mysum += i
    print('Average time taken for prediction: ',str(mysum/5))
# Out:
# Time taken to load the model and predict the value : 0:00:43.279466
# Time taken including preprocessing the audio files : 0:00:43.388766
# actual value: 23
# top 3 predicted values according to probabilities: [23  9  3]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:43.201110
# Time taken including preprocessing the audio files : 0:00:43.301465
# actual value: 11
# top 3 predicted values according to probabilities: [11 10  7]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:43.160758
# Time taken including preprocessing the audio files : 0:00:43.254544
# actual value: 5
# top 3 predicted values according to probabilities: [23 22 12]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:43.178792
# Time taken including preprocessing the audio files : 0:00:43.277165
# actual value: 2
# top 3 predicted values according to probabilities: [2 1 3]
# ----------------------------------------------------------------------------------------------------
# Time taken to load the model and predict the value : 0:00:43.064540
# Time taken including preprocessing the audio files : 0:00:43.164842
# actual value: 2
# top 3 predicted values according to probabilities: [2 1 3]
# ----------------------------------------------------------------------------------------------------
# Average time taken for prediction:  0:00:43.277356
